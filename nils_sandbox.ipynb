# %%
import statsmodels as sm
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("hackathon_prices_dev.csv")
df
# Out:
#            dates  fireworks   bread  cucumbers   cheese  candies    soil  \
# 0     2000-01-03     538.33  805.55     483.84   900.83   922.49  813.71
# 1     2000-01-04     537.79  803.72     481.04   899.64   924.84  814.22
# 2     2000-01-05     535.76  802.67     482.50   883.59   926.93  815.25
# 3     2000-01-06     536.78  806.03     483.00   834.77   926.62  814.88
# 4     2000-01-07     538.07  809.07     483.81   863.08   927.64  816.91
# ...          ...        ...     ...        ...      ...      ...     ...
# 4134  2015-12-23     920.39  812.80     778.62  1717.30  1254.30  755.67
# 4135  2015-12-24     920.39  812.80     778.62  1717.11  1254.30  755.67
# 4136  2015-12-28     920.23  814.56     778.62  1721.46  1252.12  754.76
# 4137  2015-12-29     919.05  813.48     780.03  1715.47  1252.89  756.17
# 4138  2015-12-30     919.41  817.79     780.64  1719.91  1253.08  754.75
#
#        stones    books    water  butter  tomatoes    meat     wood  diamonds  \
# 0      912.36  1120.67   896.38  312.37    666.15  816.62   601.01    609.16
# 1      888.29  1097.34   899.97  308.02    661.03  816.37   597.24    610.99
# 2      887.75  1078.77   895.40  305.77    661.64  817.59   595.80    597.53
# 3      880.25  1075.56   898.12  305.27    657.47  815.06   594.77    589.44
# 4      901.34  1091.78   900.64  305.64    657.24  817.01   598.71    592.04
# ...       ...      ...      ...     ...       ...     ...      ...       ...
# 4134  1188.63  1102.61  1455.88  556.11    785.54  960.71  1050.01    719.06
# 4135  1188.63  1102.61  1455.88  556.11    785.54  958.74  1050.01    718.25
# 4136  1188.36  1099.49  1458.12  555.97    786.72  960.70  1053.66    717.13
# 4137  1195.95  1105.69  1453.23  556.52    787.03  960.31  1050.43    718.35
# 4138  1189.97  1104.05  1453.13  554.86    785.88  962.34  1049.03    716.88
#
#       bananas
# 0      705.00
# 1      702.57
# 2      698.47
# 3      697.79
# 4      694.36
# ...       ...
# 4134   858.54
# 4135   858.54
# 4136   857.74
# 4137   859.04
# 4138   857.47
#
# [4139 rows x 16 columns]

# %%
df.index = df.dates
df.plot(figsize=(12, 8))
# Out:
# <AxesSubplot:xlabel='dates'>

# %%
from sklearn.covariance import ShrunkCovariance

# %%
prices = df.drop(columns = 'dates')
returns = prices.diff()
returns.cov()
# Out:
#            fireworks     bread  cucumbers     cheese    candies       soil  \
# fireworks   2.493730 -0.393812  -0.564134  -0.173445  -0.486503  -0.385366
# bread      -0.393812  7.973990   0.774488  -0.086964   0.380923   0.152905
# cucumbers  -0.564134  0.774488  13.333998   1.547841   2.353194   2.099706
# cheese     -0.173445 -0.086964   1.547841  51.020013   0.907930   1.042205
# candies    -0.486503  0.380923   2.353194   0.907930  11.075169   6.375967
# soil       -0.385366  0.152905   2.099706   1.042205   6.375967  11.854015
# stones     -2.633630  1.453644   3.620329   1.063331   2.033386   1.749892
#        [ 1.05147267e+04,  1.77512658e+03,  2.12606655e+04,
#          2.80322102e+04,  1.43808025e+04,  2.40725110e+03,
#          6.09098066e+03, -8.08591197e+01,  1.57107176e+04,
#          1.48420249e+04,  1.91705783e+04,  3.85913050e+03,
#          9.04180092e+03,  6.86185629e+03,  8.02399748e+03],
#        [ 4.09749076e+03, -5.46894407e+02,  6.16914449e+03,
#          1.19810116e+04,  4.56534629e+03,  8.05687494e+02,
#          3.20366190e+03,  3.93513783e+02,  6.08715904e+03,
#          4.95068058e+03,  3.85913050e+03,  4.69688390e+03,
#          4.31104335e+03,  2.41416564e+03,  1.76084514e+03],
#        [ 1.14824086e+04, -7.05988292e+02,  1.27387537e+04,
#          2.68849058e+04,  1.18193670e+04,  5.29372243e+02,
#          1.19616599e+04,  3.32226839e+03,  1.76532551e+04,
#          1.24571449e+04,  9.04180092e+03,  4.31104335e+03,
#          1.68941056e+04,  6.62710044e+03,  4.02278706e+03],
#        [ 5.17292762e+03,  7.41598544e+02,  1.12412897e+04,
#          1.48349355e+04,  7.10226390e+03,  1.15312254e+03,
#          7.34600403e+03,  3.74320274e+03,  8.16747423e+03,
#          7.63629016e+03,  6.86185629e+03,  2.41416564e+03,
#          6.62710044e+03,  7.22153269e+03,  3.19953082e+03],
#        [ 4.73762745e+03,  1.33624315e+03,  1.04179081e+04,
#          1.25479592e+04,  6.81228199e+03,  1.11104077e+03,
#          2.85483680e+03, -1.06393902e+02,  7.14189917e+03,
#          6.73008846e+03,  8.02399748e+03,  1.76084514e+03,
#          4.02278706e+03,  3.19953082e+03,  6.42470911e+03]])

# %%
def cov_shrunk(df):
    prices = df.drop(columns = ['dates'])
    cov = ShrunkCovariance().fit(prices)
    return cov.covariance_

# %%
from pypfopt.expected_returns import mean_historical_return
from pypfopt.risk_models import CovarianceShrinkage

# %%
mu = mean_historical_return(prices)

# %%
mu = mean_historical_return(prices)
S = CovarianceShrinkage(prices).ledoit_wolf()

# %%
from pypfopt.efficient_frontier import EfficientFrontier

ef = EfficientFrontier(mu, S)
weights = ef.max_sharpe()

cleaned_weights = ef.clean_weights()
print(dict(cleaned_weights))
# Out:
# {'fireworks': 0.47038, 'bread': 0.0, 'cucumbers': 0.08303, 'cheese': 0.1229, 'candies': 0.0, 'soil': 0.0, 'stones': 0.04477, 'books': 0.0, 'water': 0.0, 'butter': 0.03275, 'tomatoes': 0.0, 'meat': 0.0, 'wood': 0.24616, 'diamonds': 0.0, 'bananas': 0.0}

# %%
ef.portfolio_performance(verbose=True)
# Out:
# Expected annual return: 3.3%
# Annual volatility: 2.7%
# Sharpe Ratio: 0.49
# (0.03336669046034498, 0.02741675609798887, 0.4875372714617205)

# %%
#df.set_index('dates', inplace = True)
covariances = df.rolling(window_size).cov().shift(-1)

# %%
covariances
# Out:
#                       diamonds     butter       cars  cucumber     bananas
# dates
# 2000-01-03 diamonds        NaN        NaN        NaN       NaN         NaN
#            butter          NaN        NaN        NaN       NaN         NaN
#            cars            NaN        NaN        NaN       NaN         NaN
#            cucumber        NaN        NaN        NaN       NaN         NaN
#            bananas         NaN        NaN        NaN       NaN         NaN
# ...                        ...        ...        ...       ...         ...
# 2023-01-11 diamonds  -5.163189   8.561106  -3.094908 -0.048476  -19.975061
#            butter     3.234504  -3.094908   9.442978 -2.922378   24.304182
#            cars       0.119109  -0.048476  -2.922378  2.048404   -5.256726
#            cucumber  17.197157 -19.975061  24.304182 -5.256726  103.182083
#            bananas         NaN        NaN        NaN       NaN         NaN
#
# [29780 rows x 5 columns]

# %%
matrices = []
for date, new_df in covariances.reset_index(level=[0,1]).groupby('dates'):
    new_df.drop(columns=new_df.columns[0], axis=1, inplace=True)
    matrices.append(new_df)

# %%
matrices[20]
# Out:
#       level_1  diamonds     butter       cars   cucumber    bananas
# 100  diamonds  5.023594  26.084252  -4.726212  -5.709971 -41.720426
# 101    butter -1.603819  -4.726212   6.661015   1.690353  12.778121
# 102      cars -1.433886  -5.709971   1.690353   2.140051  12.003563
# 103  cucumber -9.097326 -41.720426  12.778121  12.003563  97.870989
# 104   bananas  3.126225   5.237453  -1.504226  -1.590827 -11.580647

# %%
len(matrices)
# Out:
# 5956

# %%
covariances.reset_index(level=[0,1])
# Out:
#             dates   level_1   diamonds     butter       cars  cucumber  \
# 0      2000-01-03  diamonds        NaN        NaN        NaN       NaN
# 1      2000-01-03    butter        NaN        NaN        NaN       NaN
# 2      2000-01-03      cars        NaN        NaN        NaN       NaN
# 3      2000-01-03  cucumber        NaN        NaN        NaN       NaN
# 4      2000-01-03   bananas        NaN        NaN        NaN       NaN
# ...           ...       ...        ...        ...        ...       ...
# 29775  2023-01-11  diamonds   4.562624  -5.163189   3.234504  0.119109
# 29776  2023-01-11    butter  -5.163189   8.561106  -3.094908 -0.048476
# 29777  2023-01-11      cars   3.234504  -3.094908   9.442978 -2.922378
# 29778  2023-01-11  cucumber   0.119109  -0.048476  -2.922378  2.048404
# 29779  2023-01-11   bananas  17.197157 -19.975061  24.304182 -5.256726
#
#           bananas
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 29775   17.197157
# 29776  -19.975061
# 29777   24.304182
# 29778   -5.256726
# 29779  103.182083
#
# [29780 rows x 7 columns]

# %% [markdown]
# # GARCH Covariance Estimate

# %%
import pandas as pd
df = pd.read_csv('hackathon_prices_dev.csv')

# %%
prices = df.set_index('dates')
returns = prices.diff()

# %%
returns
# Out:
#             fireworks  bread  cucumbers  cheese  candies  soil  stones  books  \
# dates
# 2000-01-03        NaN    NaN        NaN     NaN      NaN   NaN     NaN    NaN
# 2000-01-04      -0.54  -1.83      -2.80   -1.19     2.35  0.51  -24.07 -23.33
# 2000-01-05      -2.03  -1.05       1.46  -16.05     2.09  1.03   -0.54 -18.57
# 2000-01-06       1.02   3.36       0.50  -48.82    -0.31 -0.37   -7.50  -3.21
# 2000-01-07       1.29   3.04       0.81   28.31     1.02  2.03   21.09  16.22
# ...               ...    ...        ...     ...      ...   ...     ...    ...
# 2015-12-23       0.24   6.79       2.34    5.96    -0.86 -0.35    4.32  10.74
# 2015-12-24       0.00   0.00       0.00   -0.19     0.00  0.00    0.00   0.00
# 2015-12-28      -0.16   1.76       0.00    4.35    -2.18 -0.91   -0.27  -3.12
# 2015-12-29      -1.18  -1.08       1.41   -5.99     0.77  1.41    7.59   6.20
# 2015-12-30       0.36   4.31       0.61    4.44     0.19 -1.42   -5.98  -1.64
#
#             water  butter  tomatoes  meat  wood  diamonds  bananas
# dates
# 2000-01-03    NaN     NaN       NaN   NaN   NaN       NaN      NaN
# 2000-01-04   3.59   -4.35     -5.12 -0.25 -3.77      1.83    -2.43
# 2000-01-05  -4.57   -2.25      0.61  1.22 -1.44    -13.46    -4.10
# 2000-01-06   2.72   -0.50     -4.17 -2.53 -1.03     -8.09    -0.68
# 2000-01-07   2.52    0.37     -0.23  1.95  3.94      2.60    -3.43
# ...           ...     ...       ...   ...   ...       ...      ...
# 2015-12-23  -1.37   -0.66      1.19  1.75 -2.54      2.15     1.51
# 2015-12-24   0.00    0.00      0.00 -1.97  0.00     -0.81     0.00
# 2015-12-28   2.24   -0.14      1.18  1.96  3.65     -1.12    -0.80
# 2015-12-29  -4.89    0.55      0.31 -0.39 -3.23      1.22     1.30
# 2015-12-30  -0.10   -1.66     -1.15  2.03 -1.40     -1.47    -1.57
#
# [4139 rows x 15 columns]

# %%
from arch import arch_model
am = arch_model(returns.fireworks[1::])

# %%
res = am.fit()
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 11281184.460289426
# Iteration:      2,   Func. Count:     15,   Neg. LLF: 7914.607518086472
# Iteration:      3,   Func. Count:     21,   Neg. LLF: 7093.958769000867
# Iteration:      4,   Func. Count:     26,   Neg. LLF: 25288.07858516079
# Iteration:      5,   Func. Count:     34,   Neg. LLF: 12453.695090182135
# Iteration:      6,   Func. Count:     40,   Neg. LLF: 7087.235938246893
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 7084.182412071168
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 7084.153776895281
# Iteration:      9,   Func. Count:     56,   Neg. LLF: 7084.15367307612
# Iteration:     10,   Func. Count:     61,   Neg. LLF: 7084.152538209075
# Iteration:     11,   Func. Count:     66,   Neg. LLF: 7128.225521295444
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7084.15253814826
#             Iterations: 12
#             Function evaluations: 71
#             Gradient evaluations: 11

# %%
res
# Out:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:              fireworks   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -7084.15
# Distribution:                  Normal   AIC:                           14176.3
# Method:            Maximum Likelihood   BIC:                           14201.6
#                                         No. Observations:                 4138
# Date:                Sat, Apr 01 2023   Df Residuals:                     4137
# Time:                        11:13:30   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0348  1.622e-02      2.145  3.196e-02 [3.000e-03,6.656e-02]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      3.8012e-03  2.215e-03      1.716  8.614e-02 [-5.401e-04,8.143e-03]
# alpha[1]       0.0522  1.046e-02      4.989  6.082e-07  [3.169e-02,7.270e-02]
# beta[1]        0.9478  1.030e-02     92.018      0.000      [  0.928,  0.968]
# =============================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0x7fe5b0bbfbb0

# %%
pip install mgarch
# Out:
# Collecting mgarch
#   Downloading mgarch-0.3.0-py3-none-any.whl (4.2 kB)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from mgarch) (1.23.5)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from mgarch) (1.10.1)
# Installing collected packages: mgarch
# Successfully installed mgarch-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import mgarch

# %%
vol = mgarch.mgarch()

# %%
vol.fit(returns)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/linalg/linalg.py:2154: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)

# %%
import mgarch
vol = mgarch.mgarch()
vol.fit(returns)
ndays = 10 # volatility of nth day
cov_nextday = vol.predict(ndays)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/bq/myp7pv7d2kx50tbcnmg3pjgm0000gn/T/ipykernel_20313/533228243.py in <module>
#       1 import mgarch
#       2 vol = mgarch.mgarch()
# ----> 3 vol.fit(returns)
#       4 ndays = 10 # volatility of nth day
#       5 cov_nextday = vol.predict(ndays)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mgarch/mgarch.py in fit(self, returns)
#     149         D_t = np.zeros((self.T, self.N))
#     150         for i in range(self.N):
# --> 151             params = self.garch_fit(self.rt[:,i])
#     152             D_t[:,i] = np.sqrt(self.garch_var(params, self.rt[:,i]))
#     153         self.D_t = D_t
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mgarch/mgarch.py in garch_fit(self, returns)
#      13
#      14     def garch_fit(self, returns):
# ---> 15         res = minimize( self.garch_loglike, (0.01, 0.01, 0.94), args = returns,
#      16               bounds = ((1e-6, 1), (1e-6, 1), (1e-6, 1)))
#      17         return res.x
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     694                                  **options)
#     695     elif meth == 'l-bfgs-b':
# --> 696         res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     697                                callback=callback, **options)
#     698     elif meth == 'tnc':
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/optimize/_lbfgsb_py.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     357             # until the completion of the current minimization iteration.
#     358             # Overwrite f and g:
# --> 359             f, g = func_and_grad(x)
#     360         elif task_str.startswith(b'NEW_X'):
#     361             # new iteration
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     284             self._update_x_impl(x)
#     285         self._update_fun()
# --> 286         self._update_grad()
#     287         return self.f, self.g
#     288
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     254     def _update_grad(self):
#     255         if not self.g_updated:
# --> 256             self._update_grad_impl()
#     257             self.g_updated = True
#     258
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#     171                 self._update_fun()
#     172                 self.ngev += 1
# --> 173                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                                            **finite_diff_options)
#     175
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     503
#     504         if sparsity is None:
# --> 505             return _dense_difference(fun_wrapped, x0, f0, h,
#     506                                      use_one_sided, method)
#     507         else:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     574             x = x0 + h_vecs[i]
#     575             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 576             df = fun(x) - f0
#     577         elif method == '3-point' and use_one_sided[i]:
#     578             x1 = x0 + h_vecs[i]
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in fun_wrapped(x)
#     454
#     455     def fun_wrapped(x):
# --> 456         f = np.atleast_1d(fun(x, *args, **kwargs))
#     457         if f.ndim > 1:
#     458             raise RuntimeError("`fun` return value has "
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     135             # Overwriting results in undefined behaviour because
#     136             # fun(self.x) will change self.x, with the two no longer linked.
# --> 137             fx = fun(np.copy(x), *args)
#     138             # Make sure the function returns a true scalar
#     139             if not np.isscalar(fx):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mgarch/mgarch.py in garch_loglike(self, params, returns)
#      19     def garch_loglike(self, params, returns):
#      20         T = len(returns)
# ---> 21         var_t = self.garch_var(params, returns)
#      22         LogL = np.sum(-np.log(2*np.pi*var_t)) - np.sum( (returns.A1**2)/(2*var_t))
#      23         return -LogL
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mgarch/mgarch.py in garch_var(self, params, returns)
#      33                 var_t[i] = returns[i]**2
#      34             else:
# ---> 35                 var_t[i] = omega + alpha*(returns[i-1]**2) + beta*var_t[i-1]
#      36         return var_t
#      37
#
# KeyboardInterrupt:
